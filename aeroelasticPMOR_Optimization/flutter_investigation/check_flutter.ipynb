# %% [markdown]
# # Check Flutter

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import os
import pandas as pd
from scipy.interpolate import RBFInterpolator
from scipy.interpolate import Rbf

# %%
foldername = 'aoa_flutter_investigation'
cwd = os.getcwd()
os.chdir(cwd+'/'+foldername+'/')
data_pandas = pd.read_csv(foldername+'.csv') 
# Go back to the initial folder
os.chdir(cwd)

# %%
data_numpy = data_pandas.to_numpy()
aoa_deg = data_numpy[:,1]
ar      = data_numpy[:,2]
taper   = data_numpy[:,3]
ex      = data_numpy[:,4]
u_flutter=data_numpy[:,5]

# sort into data for ex=0.25 and ex=0.3
aoa_deg0 = aoa_deg[0:10]
aoa_deg1 = aoa_deg[10:20]
u_flutter0= u_flutter[0:10]
u_flutter1= u_flutter[10:20]

# %%
fig,ax = plt.subplots()
ax.plot(aoa_deg0,u_flutter0,'b-x')
ax.plot(aoa_deg1,u_flutter1,'r-o')


ax.legend(["ex=0.25","ex=0.30"])
ax.grid(True)
ax.set_ylabel('u_flutter (m/s)')
ax.set_xlabel('aoa (deg)')
ax.set_xlim([0,3.6])
filepath = cwd+'/figures/flutter_investigation.png'
plt.savefig(filepath, dpi=300)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
